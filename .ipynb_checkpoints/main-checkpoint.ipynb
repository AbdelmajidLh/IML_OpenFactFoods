# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# constants
url = 'https://static.openfoodfacts.org/data/en.openfoodfacts.org.products.csv.gz'
url2 = 'https://github.com/AbdelmajidLh/datasets/blob/main/en.openfoodfacts.org.products-df5.csv.gz'
url3 = 'https://github.com/Loridan/openclassrooms-iml-projects/blob/main/project2/en.openfoodfacts.org.products-df5.csv'
RAW_DATA = 'data/raw/'
save_as = 'data/raw/raw_data.gz'
logfile = "log/logfile.log"

# %%
# import packeges
import os
import pandas as pd
import tarfile
import urllib
import gzip

# %%
class GzipDownloader:
    def __init__(self, url, save_as=None):
        self.url = url
        self.save_as = save_as

    def download_unzip(self):
        # Send a GET request to the URL and get the content
        response = requests.get(self.url
        #, verify=False
        )
        data = response.content
        # Open the gzip file and decompress it
        with gzip.open(data, 'rb') as f:
            data = f.read()
        # Save the contents to a file if a filename was provided
        if self.save_as:
            with open(self.save_as, 'wb') as f:
                f.write(data)
        return data

# %%
# download and unzip data
#logger.debug("Downloading data ...")
downloader = GzipDownloader(url, save_as)
try:
    df = downloader.download_unzip()
except Exception as e:
    #logger.error("Download error", exc_info=False)
    #logger.info("Import the dataset from github ...")
    print("manually ...")
    downloader = GzipDownloader(url2, save_as)
    df = downloader.download_unzip()

df.shape
# Out:
# manually ...
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18032\120606570.py in <module>
#       4 try:
# ----> 5     df = downloader.download_unzip()
#       6 except Exception as e:
#
# ~\AppData\Local\Temp\ipykernel_18032\2913766655.py in download_unzip(self)
#      12         # Open the gzip file and decompress it
# ---> 13         with gzip.open(data, 'rb') as f:
#      14             data = f.read()
#
# ~\anaconda3\envs\py39\lib\gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      57     if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 58         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      59     elif hasattr(filename, "read") or hasattr(filename, "write"):
#
# ~\anaconda3\envs\py39\lib\gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     172         if fileobj is None:
# --> 173             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     174         if filename is None:
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x8b in position 1: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18032\120606570.py in <module>
#       9     print("manually ...")
#      10     downloader = GzipDownloader(url2, save_as)
# ---> 11     df = downloader.download_unzip()
#      12
#      13 df.shape
#
# ~\AppData\Local\Temp\ipykernel_18032\2913766655.py in download_unzip(self)
#      11         data = response.content
#      12         # Open the gzip file and decompress it
# ---> 13         with gzip.open(data, 'rb') as f:
#      14             data = f.read()
#      15         # Save the contents to a file if a filename was provided
#
# ~\anaconda3\envs\py39\lib\gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      56     gz_mode = mode.replace("t", "")
#      57     if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 58         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      59     elif hasattr(filename, "read") or hasattr(filename, "write"):
#      60         binary_file = GzipFile(None, gz_mode, compresslevel, filename)
#
# ~\anaconda3\envs\py39\lib\gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     171             mode += 'b'
#     172         if fileobj is None:
# --> 173             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     174         if filename is None:
#     175             filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: b'\n\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" data-a11y-animated-images="system">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light-719f1193e0c0.css" /><link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/dark-0c343b529849.css" /><link data-color-theme="dark_dimmed" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_dimmed-f22da508b62a.css" /><link data-color-theme="dark_high_contrast" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_high_contrast-188ef1de59e6.css" /><link data-color-theme="dark_colorblind" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_colorblind-bc6bf4eea850.css" /><link data-color-theme="light_colorblind" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_colorblind-527658dec362.css" /><link data-color-theme="light_high_contrast" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_high_contrast-c7a7fe0cd8ec.css" /><link data-color-theme="light_tritanopia" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_tritanopia-6aa855bdae0f.css" /><link data-color-theme="dark_tritanopia" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_tritanopia-6aa5e25aacc0.css" />\n  \n    <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/primer-031a7fd7c6cb.css" />\n    <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/global-735461f76c33.css" />\n    <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/github-b351ad9a2d52.css" />\n  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/code-356644123695.css" />\n\n    <meta name="optimizely-datafile" content="{&quot;groups&quot;: [], &quot;environmentKey&quot;: &quot;production&quot;, &quot;rollouts&quot;: [], &quot;typedAudiences&quot;: [], &quot;projectId&quot;: &quot;16737760170&quot;, &quot;variables&quot;: [], &quot;featureFlags&quot;: [], &quot;experiments&quot;: [], &quot;version&quot;: &quot;4&quot;, &quot;audiences&quot;: [{&quot;conditions&quot;: &quot;[\\&quot;or\\&quot;, {\\&quot;match\\&quot;: \\&quot;exact\\&quot;, \\&quot;name\\&quot;: \\&quot;$opt_dummy_attribute\\&quot;, \\&quot;type\\&quot;: \\&quot;custom_attribute\\&quot;, \\&quot;value\\&quot;: \\&quot;$opt_dummy_value\\&quot;}]&quot;, &quot;id&quot;: &quot;$opt_dummy_audience&quot;, &quot;name&quot;: &quot;Optimizely-Generated Audience for Backwards Compatibility&quot;}], &quot;anonymizeIP&quot;: true, &quot;sdkKey&quot;: &quot;WTc6awnGuYDdG98CYRban&quot;, &quot;attributes&quot;: [{&quot;id&quot;: &quot;16822470375&quot;, &quot;key&quot;: &quot;user_id&quot;}, {&quot;id&quot;: &quot;17143601254&quot;, &quot;key&quot;: &quot;spammy&quot;}, {&quot;id&quot;: &quot;18175660309&quot;, &quot;key&quot;: &quot;organization_plan&quot;}, {&quot;id&quot;: &quot;18813001570&quot;, &quot;key&quot; ...

# %%
df = pd.read_csv(url3, low_memory=False, sep='\t')

# %%
df.to_csv('data/en.openfoodfacts.org.products-df5.csv', index=False)

# %%
df.head()
# Out:
#                                      <!DOCTYPE html>
# 0  <html lang="en" data-color-mode="auto" data-li...
# 1                                             <head>
# 2                             <meta charset="utf-8">
# 3    <link rel="dns-prefetch" href="https://githu...
# 4    <link rel="dns-prefetch" href="https://avata...

# %%
df.to_csv("data/archives/en.openfoodfacts.org.products-df5.csv.gz", 
           index=False, 
           compression="gzip")

# %%
df.head()
# Out:
#      code_barres                  date_creation                   nom_produit  \
# 0  0000000000100  1970-01-01 00:00:01.444572561   moutarde au moût de raisin
# 1  0000000001281  1970-01-01 00:00:01.517830801            Tarte noix de coco
# 2  0000000001885  1970-01-01 00:00:01.511180337              Compote de poire
# 3  0000000005470  1970-01-01 00:00:01.511778860              BAguette bressan
# 4  0000000043595  1970-01-01 00:00:01.489050424                   Cranberries
#
#                                           categories      countries  \
# 0            Epicerie, Condiments, Sauces, Moutardes         France
# 1   Tartes, Tartes sucrées, Tartes à la noix de coco         France
# 2  Aliments et boissons à base de végétaux, Alime...         France
# 3  Aliments et boissons à base de végétaux, Alime...         France
# 4  Plant-based foods and beverages, Plant-based f...  United States
#
#    nutriscore_score nutriscore_grade         pnns_groupes_1  \
# 0              18.0                d         Fat and sauces
# 1              14.0                d          Sugary snacks
# 2              -2.0                a  Fruits and vegetables
# 3              -4.0                a   Cereals and potatoes
# 4               3.0                c  Fruits and vegetables
#
#          pnns_groupes_2  energie_100g  matieres_grasses_100g  \
# 0  Dressings and sauces         936.0                    8.2
# 1    Biscuits and cakes        1594.0                   22.0
# 2                Fruits         657.0                    0.0
# 3                 Bread         669.0                    2.2
# 4                Fruits        1255.0                    0.0
#
#    matieres_grasses_saturees_100g  glucides_100g  glucides_sucres_100g  \
# 0                             2.2          29.00                 22.00
# 1                            15.5          27.30                 21.90
# 2                             0.0          36.00                 27.00
# 3                             0.5          25.20                  0.60
# 4                             0.0          83.33                 66.67
#
#    fibres_100g  proteines_100g  sel_100g  sodium_100g
# 0          0.0             5.1     4.600       1.8400
# 1          4.4             4.6     0.100       0.0400
# 2          3.6             0.6     0.000       0.0000
# 3          1.6             9.5     0.358       0.1432
# 4         10.0             0.0     0.000       0.0000

# %%
gz_path=save_as
urllib.request.urlretrieve(url, gz_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18032\3443116425.py in <module>
#       1 gz_path=save_as
# ----> 2 urllib.request.urlretrieve(url, gz_path)
#
# ~\anaconda3\envs\py39\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     266
#     267             while True:
# --> 268                 block = fp.read(bs)
#     269                 if not block:
#     270                     break
#
# ~\anaconda3\envs\py39\lib\http\client.py in read(self, amt)
#     461             # Amount is given, implement using readinto
#     462             b = bytearray(amt)
# --> 463             n = self.readinto(b)
#     464             return memoryview(b)[:n].tobytes()
#     465         else:
#
# ~\anaconda3\envs\py39\lib\http\client.py in readinto(self, b)
#     505         # connection, and the user is reading more bytes than will be provided
#     506         # (for example, reading in 1k chunks)
# --> 507         n = self.fp.readinto(b)
#     508         if not n and b:
#     509             # Ideally, we would raise IncompleteRead if the content-length
#
# ~\anaconda3\envs\py39\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~\anaconda3\envs\py39\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#    1244             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\envs\py39\lib\ssl.py in read(self, len, buffer)
#    1098         try:
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#    1102                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # download and unzip data

# %%
#logger.debug("Downloading data ...")
downloader = GzipDownloader(url, save_as)
try:
    df = downloader.download_unzip()
except Exception as e:
    #logger.error("Download error", exc_info=True)
    print("error")
# Out:
# error

# %% [markdown]
# # import csv from link

# %%
import csv
import urllib.request

class CSVDownloader:
    def __init__(self):
        self.url = ""

    def download_csv(self, link):
        self.url = link
        response = urllib.request.urlopen(self.url)
        csv_file = response.read().decode('utf-8')
        csv_reader = csv.reader(csv_file.splitlines(), delimiter=',')
        csv_data = list(csv_reader)
        return csv_data

# %%
downloader = CSVDownloader()
data = downloader.download_csv(url2)
print(data)
# Out:
# [[], [], [], [], [], [], [], ['<!DOCTYPE html>'], ['<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" data-a11y-animated-images="system">'], ['  <head>'], ['    <meta charset="utf-8">'], ['  <link rel="dns-prefetch" href="https://github.githubassets.com">'], ['  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">'], ['  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">'], ['  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">'], ['  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>'], ['  <link rel="preconnect" href="https://avatars.githubusercontent.com">'], [], [], [], ['  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light-719f1193e0c0.css" /><link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/dark-0c343b529849.css" /><link data-color-theme="dark_dimmed" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_dimmed-f22da508b62a.css" /><link data-color-theme="dark_high_contrast" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_high_contrast-188ef1de59e6.css" /><link data-color-theme="dark_colorblind" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_colorblind-bc6bf4eea850.css" /><link data-color-theme="light_colorblind" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_colorblind-527658dec362.css" /><link data-color-theme="light_high_contrast" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_high_contrast-c7a7fe0cd8ec.css" /><link data-color-theme="light_tritanopia" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_tritanopia-6aa855bdae0f.css" /><link data-color-theme="dark_tritanopia" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_tritanopia-6aa5e25aacc0.css" />'], ['  '], ['    <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/primer-031a7fd7c6cb.css" />'], ['    <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/global-735461f76c33.css" />'], ['    <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/github-b351ad9a2d52.css" />'], ['  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/code-356644123695.css" />'], [], ['    <meta name="optimizely-datafile" content="{&quot;groups&quot;: []', ' &quot;environmentKey&quot;: &quot;production&quot;', ' &quot;rollouts&quot;: []', ' &quot;typedAudiences&quot;: []', ' &quot;projectId&quot;: &quot;16737760170&quot;', ' &quot;variables&quot;: []', ' &quot;featureFlags&quot;: []', ' &quot;experiments&quot;: []', ' &quot;version&quot;: &quot;4&quot;', ' &quot;audiences&quot;: [{&quot;conditions&quot;: &quot;[\\&quot;or\\&quot;', ' {\\&quot;match\\&quot;: \\&quot;exact\\&quot;', ' \\&quot;name\\&quot;: \\&quot;$opt_dummy_attribute\\&quot;', ' \\&quot;type\\&quot;: \\&quot;custom_attribute\\&quot;', ' \\&quot;value\\&quot;: \\&quot;$opt_dummy_value\\&quot;}]&quot;', ' &quot;id&quot;: &quot;$opt_dummy_audience&quot;', ' &quot;name&quot;: &quot;Optimizely-Generated Audience for Backwards Compatibility&quot;}]', ' &quot;anonymizeIP&quot;: true', ' &quot;sdkKey&quot;: &quot;WTc6awnGuYDdG98CYRban&quot;', ' &quot;attributes&quot;: [{&quot;id&quot;: &quot;16822470375&quot;', ' &quot;key&quot;: &quot;user_id&quot;}', ' {&quot;id&quot;: &quot;17143601254&quot;', ' &quot;key&quot;: &quot;spammy&quot;}', ' {&quot;id&quot;: &quot;18175660309&quot;', ' &quot; ...

# %% [markdown]
# # import csv.gz from a link

# %%
import gzip
import urllib.request
import io
import csv

class CSVDownloader:
    def __init__(self):
        self.url = ""

    def download_and_uncompress_csv(self, link):
        self.url = link
        response = urllib.request.urlopen(self.url)
        compressed_file = response.read()
        decompressed_file = gzip.decompress(compressed_file)
        #Convert bytes to string
        csv_file = decompressed_file.decode()
        csv_reader = csv.reader(csv_file.splitlines(), delimiter=';')
        csv_data = list(csv_reader)
        return csv_data

# %%
downloader = CSVDownloader()
data = downloader.download_and_uncompress_csv(url2)
print(data)
# Out:
# ---------------------------------------------------------------------------
# BadGzipFile                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18032\2952253784.py in <module>
#       1 downloader = CSVDownloader()
# ----> 2 data = downloader.download_and_uncompress_csv(url2)
#       3 print(data)
#
# ~\AppData\Local\Temp\ipykernel_18032\115280540.py in download_and_uncompress_csv(self, link)
#      12         response = urllib.request.urlopen(self.url)
#      13         compressed_file = response.read()
# ---> 14         decompressed_file = gzip.decompress(compressed_file)
#      15         #Convert bytes to string
#      16         csv_file = decompressed_file.decode()
#
# ~\anaconda3\envs\py39\lib\gzip.py in decompress(data)
#     554     """
#     555     with GzipFile(fileobj=io.BytesIO(data)) as f:
# --> 556         return f.read()
#     557
#     558
#
# ~\anaconda3\envs\py39\lib\gzip.py in read(self, size)
#     298             import errno
#     299             raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 300         return self._buffer.read(size)
#     301
#     302     def read1(self, size=-1):
#
# ~\anaconda3\envs\py39\lib\gzip.py in read(self, size)
#     485                 # jump to the next member, if there is one.
#     486                 self._init_read()
# --> 487                 if not self._read_gzip_header():
#     488                     self._size = self._pos
#     489                     return b""
#
# ~\anaconda3\envs\py39\lib\gzip.py in _read_gzip_header(self)
#     433
#     434         if magic != b'\037\213':
# --> 435             raise BadGzipFile('Not a gzipped file (%r)' % magic)
#     436
#     437         (method, flag,
#
# BadGzipFile: Not a gzipped file (b'\n\n')

# %% [markdown]
# ## exemple 2

# %%
import os
import tarfile
import urllib.request

class CSVDownloader:
    def __init__(self):
        self.url = ""
        self.file_name = ""
    
    def download_csv(self, link):
        self.url = link
        self.file_name = link.split("/")[-1]
        urllib.request.urlretrieve(self.url, self.file_name)
        if self.file_name.endswith("gz"):
            tar = tarfile.open(self.file_name, "r:gz")
            tar.extractall()
            tar.close()
            os.remove(self.file_name)
            return self.file_name.replace(".gz", "")
        else:
            return self.file_name

# %%
downloader = CSVDownloader()
file_name = downloader.download_csv(url2)
print(file_name)
# Out:
# ---------------------------------------------------------------------------
# BadGzipFile                               Traceback (most recent call last)
# ~\anaconda3\envs\py39\lib\tarfile.py in gzopen(cls, name, mode, fileobj, compresslevel, **kwargs)
#    1690         try:
# -> 1691             t = cls.taropen(name, mode, fileobj, **kwargs)
#    1692         except OSError:
#
# ~\anaconda3\envs\py39\lib\tarfile.py in taropen(cls, name, mode, fileobj, **kwargs)
#    1667             raise ValueError("mode must be 'r', 'a', 'w' or 'x'")
# -> 1668         return cls(name, mode, fileobj, **kwargs)
#    1669
#
# ~\anaconda3\envs\py39\lib\tarfile.py in __init__(self, name, mode, fileobj, format, tarinfo, dereference, ignore_zeros, encoding, errors, pax_headers, debug, errorlevel, copybufsize)
#    1530                 self.firstmember = None
# -> 1531                 self.firstmember = self.next()
#    1532
#
# ~\anaconda3\envs\py39\lib\tarfile.py in next(self)
#    2362                     else:
# -> 2363                         raise e
#    2364                 except ImportError:
#
# ~\anaconda3\envs\py39\lib\tarfile.py in next(self)
#    2335             try:
# -> 2336                 tarinfo = self.tarinfo.fromtarfile(self)
#    2337             except EOFHeaderError as e:
#
# ~\anaconda3\envs\py39\lib\tarfile.py in fromtarfile(cls, tarfile)
#    1120         """
# -> 1121         buf = tarfile.fileobj.read(BLOCKSIZE)
#    1122         obj = cls.frombuf(buf, tarfile.encoding, tarfile.errors)
#
# ~\anaconda3\envs\py39\lib\gzip.py in read(self, size)
#     299             raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 300         return self._buffer.read(size)
#     301
#
# ~\anaconda3\envs\py39\lib\_compression.py in readinto(self, b)
#      67         with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68             data = self.read(len(byte_view))
#      69             byte_view[:len(data)] = data
#
# ~\anaconda3\envs\py39\lib\gzip.py in read(self, size)
#     486                 self._init_read()
# --> 487                 if not self._read_gzip_header():
#     488                     self._size = self._pos
#
# ~\anaconda3\envs\py39\lib\gzip.py in _read_gzip_header(self)
#     434         if magic != b'\037\213':
# --> 435             raise BadGzipFile('Not a gzipped file (%r)' % magic)
#     436
#
# BadGzipFile: Not a gzipped file (b'\n\n')
#
# During handling of the above exception, another exception occurred:
#
# ReadError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18032\2813116893.py in <module>
#       1 downloader = CSVDownloader()
# ----> 2 file_name = downloader.download_csv(url2)
#       3 print(file_name)
#
# ~\AppData\Local\Temp\ipykernel_18032\871374703.py in download_csv(self, link)
#      13         urllib.request.urlretrieve(self.url, self.file_name)
#      14         if self.file_name.endswith("gz"):
# ---> 15             tar = tarfile.open(self.file_name, "r:gz")
#      16             tar.extractall()
#      17             tar.close()
#
# ~\anaconda3\envs\py39\lib\tarfile.py in open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1636             else:
#    1637                 raise CompressionError("unknown compression type %r" % comptype)
# -> 1638             return func(name, filemode, fileobj, **kwargs)
#    1639
#    1640         elif "|" in mode:
#
# ~\anaconda3\envs\py39\lib\tarfile.py in gzopen(cls, name, mode, fileobj, compresslevel, **kwargs)
#    1693             fileobj.close()
#    1694             if mode == 'r':
# -> 1695                 raise ReadError("not a gzip file")
#    1696             raise
#    1697         except:
#
# ReadError: not a gzip file

# %% [markdown]
# # from a zip file

# %%
import os
import zipfile
import urllib.request
import pandas as pd

class CSVDownloader:
    def __init__(self):
        self.url = ""
        self.file_name = ""

    def download_csv(self, link):
        self.url = link
        self.file_name = link.split("/")[-1]
        urllib.request.urlretrieve(self.url, self.file_name)

        with zipfile.ZipFile(self.file_name, 'r') as zip_ref:
            zip_ref.extractall()

        for file in os.listdir():
            if file.endswith('.csv'):
                csv_file = file
                break
        os.remove(self.file_name)
        df = pd.read_csv(csv_file, low_memory=False)
        return df

# %% [markdown]
# ## updated class

# %%
import os
import zipfile
import urllib.request
import pandas as pd

class CSVDownloader:
    def __init__(self):
        self.url = ""
        self.file_name = ""

    def download_csv(self, link):
        self.url = link
        self.file_name = link.split("/")[-1]
        raw_data_path = "data/raw"
        if not os.path.exists(raw_data_path):
            os.makedirs(raw_data_path)
        urllib.request.urlretrieve(self.url, f"{raw_data_path}/{self.file_name}")

        with zipfile.ZipFile(f"{raw_data_path}/{self.file_name}", 'r') as zip_ref:
            zip_ref.extractall(raw_data_path)

        for file in os.listdir(raw_data_path):
            if file.endswith('.csv'):
                csv_file = file
                break
        os.remove(f"{raw_data_path}/{self.file_name}")
        df = pd.read_csv(f"{raw_data_path}/{csv_file}", low_memory=False)
        return df

# %%
downloader = CSVDownloader()
df = downloader.download_csv("https://github.com/AbdelmajidLh/datasets/raw/main/en.openfoodfacts.org.products-df5.zip")
print(df.head())
# Out:
#      code_barres                  date_creation                   nom_produit  \
# 0  0000000000100  1970-01-01 00:00:01.444572561   moutarde au moût de raisin
# 1  0000000001281  1970-01-01 00:00:01.517830801            Tarte noix de coco
# 2  0000000001885  1970-01-01 00:00:01.511180337              Compote de poire
# 3  0000000005470  1970-01-01 00:00:01.511778860              BAguette bressan
# 4  0000000043595  1970-01-01 00:00:01.489050424                   Cranberries
#
#                                           categories      countries  \
# 0            Epicerie, Condiments, Sauces, Moutardes         France
# 1   Tartes, Tartes sucrées, Tartes à la noix de coco         France
# 2  Aliments et boissons à base de végétaux, Alime...         France
# 3  Aliments et boissons à base de végétaux, Alime...         France
# 4  Plant-based foods and beverages, Plant-based f...  United States
#
#    nutriscore_score nutriscore_grade         pnns_groupes_1  \
# 0              18.0                d         Fat and sauces
# 1              14.0                d          Sugary snacks
# 2              -2.0                a  Fruits and vegetables
# 3              -4.0                a   Cereals and potatoes
# 4               3.0                c  Fruits and vegetables
#
#          pnns_groupes_2  energie_100g  matieres_grasses_100g  \
# 0  Dressings and sauces         936.0                    8.2
# 1    Biscuits and cakes        1594.0                   22.0
# 2                Fruits         657.0                    0.0
# 3                 Bread         669.0                    2.2
# 4                Fruits        1255.0                    0.0
#
#    matieres_grasses_saturees_100g  glucides_100g  glucides_sucres_100g  \
# 0                             2.2          29.00                 22.00
# 1                            15.5          27.30                 21.90
# 2                             0.0          36.00                 27.00
# 3                             0.5          25.20                  0.60
# 4                             0.0          83.33                 66.67
#
#    fibres_100g  proteines_100g  sel_100g  sodium_100g
# 0          0.0             5.1     4.600       1.8400
# 1          4.4             4.6     0.100       0.0400
# 2          3.6             0.6     0.000       0.0000
# 3          1.6             9.5     0.358       0.1432
# 4         10.0             0.0     0.000       0.0000

# %% [markdown]
# # from a csv file with checks

# %%
import pandas as pd

class CSVImporter:
    def __init__(self):
        self.file_name = ""

    def import_csv(self, file_name):
        self.file_name = file_name
        try:
            df = pd.read_csv(self.file_name, low_memory=False)
            if df.empty:
                raise ValueError("The file is empty")
            return df
        except FileNotFoundError:
            raise FileNotFoundError("The file does not exist")

# %%
importer = CSVImporter()
df = importer.import_csv("data/raw/en.openfoodfacts.org.products-df5.csv")
print(df.head())
# Out:
#      code_barres                  date_creation                   nom_produit  \
# 0  0000000000100  1970-01-01 00:00:01.444572561   moutarde au moût de raisin
# 1  0000000001281  1970-01-01 00:00:01.517830801            Tarte noix de coco
# 2  0000000001885  1970-01-01 00:00:01.511180337              Compote de poire
# 3  0000000005470  1970-01-01 00:00:01.511778860              BAguette bressan
# 4  0000000043595  1970-01-01 00:00:01.489050424                   Cranberries
#
#                                           categories      countries  \
# 0            Epicerie, Condiments, Sauces, Moutardes         France
# 1   Tartes, Tartes sucrées, Tartes à la noix de coco         France
# 2  Aliments et boissons à base de végétaux, Alime...         France
# 3  Aliments et boissons à base de végétaux, Alime...         France
# 4  Plant-based foods and beverages, Plant-based f...  United States
#
#    nutriscore_score nutriscore_grade         pnns_groupes_1  \
# 0              18.0                d         Fat and sauces
# 1              14.0                d          Sugary snacks
# 2              -2.0                a  Fruits and vegetables
# 3              -4.0                a   Cereals and potatoes
# 4               3.0                c  Fruits and vegetables
#
#          pnns_groupes_2  energie_100g  matieres_grasses_100g  \
# 0  Dressings and sauces         936.0                    8.2
# 1    Biscuits and cakes        1594.0                   22.0
# 2                Fruits         657.0                    0.0
# 3                 Bread         669.0                    2.2
# 4                Fruits        1255.0                    0.0
#
#    matieres_grasses_saturees_100g  glucides_100g  glucides_sucres_100g  \
# 0                             2.2          29.00                 22.00
# 1                            15.5          27.30                 21.90
# 2                             0.0          36.00                 27.00
# 3                             0.5          25.20                  0.60
# 4                             0.0          83.33                 66.67
#
#    fibres_100g  proteines_100g  sel_100g  sodium_100g
# 0          0.0             5.1     4.600       1.8400
# 1          4.4             4.6     0.100       0.0400
# 2          3.6             0.6     0.000       0.0000
# 3          1.6             9.5     0.358       0.1432
# 4         10.0             0.0     0.000       0.0000

# %% [markdown]
# # telecharger et décompresser un zip file

# %%
import urllib.request
import zipfile
import os

class FileDownloader:
    def __init__(self):
        self.url = ""
        self.file_name = ""

    def download_and_unzip(self, link):
        self.url = link
        self.file_name = link.split("/")[-1]
        urllib.request.urlretrieve(self.url, self.file_name)
        with zipfile.ZipFile(self.file_name, 'r') as zip_ref:
            zip_ref.extractall()
        os.remove(self.file_name)

# %%
downloader = FileDownloader()
downloader.download_and_unzip("https://github.com/AbdelmajidLh/datasets/raw/main/en.openfoodfacts.org.products-df5.zip")
